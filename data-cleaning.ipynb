# %%
import pandas as pd

data ={
    "assignment":[2,4,6,8,10],
    "project":[5,6,6,7,8],
    "marks":[40,50,60,85,95]

}
df =pd .DataFrame(data)
df["internals"]=df["assignment"]+df["project"]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

x = df[["marks" , "internals" , "project"]]
y = df[["assignment"]]

selector = SelectKBest(score_func=f_regression, k=2)

X_seleted = selector.fit_transform(x,y)

print(X_seleted)
# Out:
# [[40  7]
#  [50 10]
#  [60 12]
#  [85 15]
#  [95 18]]
# c:\Users\Ankitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
import pandas as pd
import numpy as np
from  sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

data = {
    "cloud" : [2,4,5,6,7],
    "web-pro": [3,6,7,8,8],
    "ml":[4,8,6,9,5]
}

df = pd.DataFrame(data)

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

pca = PCA(n_components=2)

principal_components = pca.fit_transform(scaled_data)

print(principal_components)
# Out:
# [[-2.76975507 -0.09554991]
#  [-0.04749153  1.00232591]
#  [ 0.18818068 -0.30001547]
#  [ 1.61029259  0.77353476]
#  [ 1.01877333 -1.38029529]]

# %%
import matplotlib.pyplot as plt

plt.scatter(principal_components[:,0], principal_components[:,1])

plt.xlabel("principal component 1")
plt.ylabel("principal component 2")

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.scatter(principal_components[:,0], principal_components[:,1])
#       5 plt.xlabel("principal component 1")
#
# ModuleNotFoundError: No module named 'matplotlib'
